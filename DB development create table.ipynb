# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# %load_ext sql

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
DB_ENDPOINT = os.getenv('DB_ENDPOINT', '')
DB_USER = os.getenv('DB_USER', '')
DB_PASSWORD = os.getenv('DB_PASSWORD', '')
DB_PORT = os.getenv('DB_PORT', '')


# postgresql://username:password@host:port/database
conn_string = f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_ENDPOINT}:{DB_PORT}/{DB}"
conn_string = f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_ENDPOINT}:{DB_PORT}"

print(conn_string)
# Out:
# postgresql://postgres:mDLevXKqY587JSA@database-2-xoel.clbhfzyewooy.us-west-2.rds.amazonaws.com:5432

# %%
# %sql $conn_string
# Out:
# 'Connected: postgres@None'

# %%
# %sql select * from information_schema.schemata
# Out:
#  * postgresql://postgres:***@database-2-xoel.clbhfzyewooy.us-west-2.rds.amazonaws.com:5432
# 5 rows affected.
# [('postgres', 'public', 'postgres', None, None, None, None),
#  ('postgres', 'information_schema', 'rdsadmin', None, None, None, None),
#  ('postgres', 'pg_catalog', 'rdsadmin', None, None, None, None),
#  ('postgres', 'pg_toast_temp_1', 'rdsadmin', None, None, None, None),
#  ('postgres', 'pg_temp_1', 'rdsadmin', None, None, None, None)]

# %%
# %sql SET SCHEMA 'public'
# Out:
#  * postgresql://postgres:***@database-2-xoel.clbhfzyewooy.us-west-2.rds.amazonaws.com:5432
# Done.
# []

# %%
# %%sql
#
# SELECT * FROM information_schema.tables
# WHERE table_schema = 'public'
# Out:
#  * postgresql://postgres:***@database-2-xoel.clbhfzyewooy.us-west-2.rds.amazonaws.com:5432
# 0 rows affected.
# []

# %%
import pandas as pd

# %%
df = pd.read_csv('data/likes_raw.csv')
df
# Out:
#                           Date  \
# 0     2020-01-22T18:14:34.000Z
# 1     2019-12-31T22:02:46.000Z
# 2     2020-01-20T18:49:36.000Z
# 3     2020-01-22T20:28:07.000Z
# 4     2019-05-12T18:19:16.000Z
# 5     2020-01-23T07:26:13.000Z
# 6     2019-12-31T14:52:25.000Z
# 7     2020-01-21T05:54:22.000Z
# 8     2019-12-30T10:03:44.000Z
# 9     2020-01-23T20:03:36.000Z
# 10    2020-01-22T10:44:48.000Z
# 11    2020-01-23T08:19:13.000Z
# 12    2019-05-12T17:03:02.000Z
# 13    2020-01-24T08:32:14.000Z
# 14    2019-12-30T14:24:50.000Z
# 15    2019-05-12T03:39:27.000Z
# 16    2019-05-11T23:02:04.000Z
# 17    2020-01-21T09:43:47.000Z
# 18    2020-01-23T20:04:51.000Z
# 19    2020-01-21T17:31:16.000Z
# 20    2019-12-31T16:40:28.000Z
# 21    2020-01-23T08:47:46.000Z
# 22    2019-12-31T16:01:36.000Z
# 23    2020-01-21T21:08:02.000Z
# 24    2020-01-24T13:42:30.000Z
# 25    2020-01-22T15:00:54.000Z
# 26    2020-01-22T19:19:42.000Z
# 27    2019-05-11T16:53:30.000Z
# 28    2019-12-30T18:05:03.000Z
# ...

# %%
df.dtypes
# Out:
# Date                      object
# Tweet                     object
# User logo                 object
# User alias                object
# Text                      object
# Media                     object
# User name                 object
# Location                  object
# User bio                  object
# URL                       object
# Likes                      int64
# RTs                        int64
# User follower count        int64
# Logo user quoted tweet    object
# Quoted tweet text         object
# User alias quoted         object
# User name quoted          object
# ID                         int64
# dtype: object

# %%
for i, v in df.dtypes.iteritems():
    if v == 'object':
        sql_type = 'varchar'
    elif v == 'int64':
        sql_type = 'bigint'
    print(f"{i.lower().replace(' ', '_')} {sql_type.upper()},")
# Out:
# date VARCHAR,
# tweet VARCHAR,
# user_logo VARCHAR,
# user_alias VARCHAR,
# text VARCHAR,
# media VARCHAR,
# user_name VARCHAR,
# location VARCHAR,
# user_bio VARCHAR,
# url VARCHAR,
# likes BIGINT,
# rts BIGINT,
# user_follower_count BIGINT,
# logo_user_quoted_tweet VARCHAR,
# quoted_tweet_text VARCHAR,
# user_alias_quoted VARCHAR,
# user_name_quoted VARCHAR,
# id BIGINT,

# %%
# %%sql
#
# CREATE TABLE likes (
#     date VARCHAR,
#     tweet VARCHAR,
#     user_logo VARCHAR,
#     user_alias VARCHAR,
#     text VARCHAR,
#     media VARCHAR,
#     user_name VARCHAR,
#     location VARCHAR,
#     user_bio VARCHAR,
#     url VARCHAR,
#     likes BIGINT,
#     rts BIGINT,
#     user_follower_count BIGINT,
#     logo_user_quoted_tweet VARCHAR,
#     quoted_tweet_text VARCHAR,
#     user_alias_quoted VARCHAR,
#     user_name_quoted VARCHAR,
#     id BIGINT
# );
# Out:
#  * postgresql://postgres:***@database-2-xoel.clbhfzyewooy.us-west-2.rds.amazonaws.com:5432
# Done.
# []

# %%
# %%sql
#
# SELECT * FROM information_schema.tables
# WHERE table_schema = 'public'
# Out:
#  * postgresql://postgres:***@database-2-xoel.clbhfzyewooy.us-west-2.rds.amazonaws.com:5432
# 1 rows affected.
# [('postgres', 'public', 'likes', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None)]

# %%
# %sql select * from information_schema.tables
# Out:
#  * postgresql://postgres:***@database-2-xoel.clbhfzyewooy.us-west-2.rds.amazonaws.com:5432
# 185 rows affected.
# [('postgres', 'public', 'likes', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('postgres', 'pg_catalog', 'pg_type', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('postgres', 'pg_catalog', 'pg_foreign_server', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('postgres', 'pg_catalog', 'pg_roles', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('postgres', 'pg_catalog', 'pg_settings', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('postgres', 'pg_catalog', 'pg_cursors', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('postgres', 'pg_catalog', 'pg_stat_bgwriter', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('postgres', 'pg_catalog', 'pg_subscription', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
# ...

# %%
from config import ROOT_DIR
import os

# %%
print(ROOT_DIR)
# Out:
# /Users/xoel/CODE/Projects/twitter_likes

# %%
likes_path = os.path.join(ROOT_DIR, 'data/likes_raw.csv')
likes_path
# Out:
# '/Users/xoel/CODE/Projects/twitter_likes/data/likes_raw.csv'

# %%
import psycopg2
conn = psycopg2.connect(f"""
    host={DB_ENDPOINT} 
    user={DB_USER} 
    password={DB_PASSWORD}
    port={DB_PORT}""")
conn.autocommit = True
cur = conn.cursor()

# %%
r = cur.execute('select * from information_schema.tables')

# %%
print(cur.fetchall())
# Out:
# [('postgres', 'public', 'likes', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None), ('postgres', 'pg_catalog', 'pg_type', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None), ('postgres', 'pg_catalog', 'pg_foreign_server', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None), ('postgres', 'pg_catalog', 'pg_roles', 'VIEW', None, None, None, None, None, 'NO', 'NO', None), ('postgres', 'pg_catalog', 'pg_settings', 'VIEW', None, None, None, None, None, 'NO', 'NO', None), ('postgres', 'pg_catalog', 'pg_cursors', 'VIEW', None, None, None, None, None, 'NO', 'NO', None), ('postgres', 'pg_catalog', 'pg_stat_bgwriter', 'VIEW', None, None, None, None, None, 'NO', 'NO', None), ('postgres', 'pg_catalog', 'pg_subscription', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None), ('postgres', 'pg_catalog', 'pg_stat_progress_vacuum', 'VIEW', None, None, None, None, None, 'NO', 'NO', None), ('postgres', 'pg_catalog', 'pg_stat_progress_cluster', 'VIEW', None, 
# ...

# %%
copy_csv_pg_statement = f"COPY likes FROM '{likes_path}' DELIMITER ',' CSV HEADER;"
copy_csv_pg_statement
# Out:
# "COPY likes FROM '/Users/xoel/CODE/Projects/twitter_likes/likes_raw.csv' DELIMITER ',' CSV HEADER;"

# %%
cur.execute(copy_csv_pg_statement)
# Out:
# ---------------------------------------------------------------------------
# InsufficientPrivilege                     Traceback (most recent call last)
# <ipython-input-83-ce603b2c3b94> in <module>
# ----> 1 cur.execute(copy_csv_pg_statement)
#
# InsufficientPrivilege: must be superuser or a member of the pg_read_server_files role to COPY from a file
# HINT:  Anyone can COPY to stdout or from stdin. psql's \copy command also works for anyone.

# %%
DB_USER
# Out:
# 'postgres'

# %%
# %sql ALTER USER postgres WITH SUPERUSER;
# Out:
#  * postgresql://postgres:***@database-2-xoel.clbhfzyewooy.us-west-2.rds.amazonaws.com:5432
# (psycopg2.errors.InsufficientPrivilege) must be superuser to alter superusers
#
# [SQL: ALTER USER postgres WITH SUPERUSER;]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %sql $copy_csv_pg_statement
# Out:
#  * postgresql://postgres:***@database-2-xoel.clbhfzyewooy.us-west-2.rds.amazonaws.com:5432
# (psycopg2.errors.InsufficientPrivilege) must be superuser or a member of the pg_read_server_files role to COPY from a file
# HINT:  Anyone can COPY to stdout or from stdin. psql's \copy command also works for anyone.
#
# [SQL: COPY likes FROM '/Users/xoel/CODE/Projects/twitter_likes/likes_raw.csv' DELIMITER ',' CSV HEADER;]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
conn
# Out:
# <connection object at 0x1197ce828; dsn: 'user=postgres password=xxx host=database-2-xoel.clbhfzyewooy.us-west-2.rds.amazonaws.com port=5432', closed: 0>

# %%
df.to_sql('likes', con=conn, schema='public')
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# ~/.local/share/virtualenvs/twitter_likes-LY3vHxM1/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1430             else:
# -> 1431                 cur.execute(*args)
#    1432             return cur
#
# UndefinedTable: relation "sqlite_master" does not exist
# LINE 1: SELECT name FROM sqlite_master WHERE type='table' AND name=?...
#                          ^
#
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-99-e3a846d34964> in <module>
# ----> 1 df.to_sql('likes', con=conn, schema='public')
#
# ...

# %%
# %sql select * from likes limit 100
# Out:
#  * postgresql://postgres:***@database-2-xoel.clbhfzyewooy.us-west-2.rds.amazonaws.com:5432
# 100 rows affected.
# [('2020-01-22T18:14:34.000Z', None, 'https://pbs.twimg.com/profile_images/1254774015928856583/Is0rCFWC_200x200.jpg', 'PrisonPlanet', "Here's how Ecudaor disposes of their litter.\n\nGreta going to be visiting Quito any time soon, or just lecturing the U.S. &amp; Europe?\n\nhttps://t.co/AiXwhXUuM3", None, 'Paul Joseph Watson', 'London', '"Watson is a brilliant polemicist." The Spectator.....”Free speech extremist.” The Mirror.', 'https://twitter.com/gojonewsnow/status/1218235541512228864/video/1', 28217, 11830, 1142902, None, None, None, None, 1220047117537947661),
# ...
